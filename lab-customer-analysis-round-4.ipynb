# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
file = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')
file.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
file.shape
# Out:
# (9134, 24)

# %%
file.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
numerica = file.select_dtypes(include = np.number)
categoricals = file.select_dtypes(include = object)

# %%
#General distribution plot for all the numerical variables
plt.figure(figsize=(15,8), dpi=80)
sns.displot(numerical)
plt.show()

# %%
#Distribution plots for the numerical variables.
for i in range(7):
    sns.displot(numerical.iloc[i])
    plt.show()

# %%
#Histograms.
for i in range(7):
    numerical.iloc[i].hist(bins=20)
    plt.show()

# %%
numerical.min()
# Out:
# Customer Lifetime Value          1898.007675
# Income                              0.000000
# Monthly Premium Auto               61.000000
# Months Since Last Claim             0.000000
# Months Since Policy Inception       0.000000
# Number of Open Complaints           0.000000
# Number of Policies                  1.000000
# Total Claim Amount                  0.099007
# dtype: float64

# %%
from scipy import stats

# %%
#Become to normal distribution.
mu, sigma = numerical['Customer Lifetime Value'].mean(), numerical['Customer Lifetime Value'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Income'].mean(), numerical['Income'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Monthly Premium Auto'].mean(), numerical['Monthly Premium Auto'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Months Since Last Claim'].mean(), numerical['Months Since Last Claim'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Months Since Policy Inception'].mean(), numerical['Months Since Policy Inception'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Number of Open Complaints'].mean(), numerical['Number of Open Complaints'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Number of Policies'].mean(), numerical['Number of Policies'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()
mu, sigma = numerical['Total Claim Amount'].mean(), numerical['Total Claim Amount'].std()
x = mu + sigma * np.random.randn(5000)
sns.displot(x,bins=50)
plt.show()

# %%
#Check the multicollinearity between the features
plt.figure(figsize=(15,8), dpi=80)
correlations_matrix = file.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
#There is not a strong correlation betwean any feature, we can say that the most correlated features are the total claim amount, customer lifetime value, income, and monthly premium auto.

# %%
#There is not correlation coeficiente bigger than 0.9
